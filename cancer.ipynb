# %%
import pandas as pd

dataset = pd.read_csv('cancer.csv')

# %%
x = dataset.drop(columns = ['diagnosis(1=m, 0=b)'])

# %%
y = dataset['diagnosis(1=m, 0=b)']

# %% [markdown]
# Split out our data into training set and testing set:

# %%
from sklearn.model_selection import train_test_split    # here used only to split data between training set and testing set

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# Now for the AI code, using Keras:

# %%
import tensorflow as tf
model = tf.keras.models.Sequential()

# %% [markdown]
# To add nodes/layers of a network:
#
# ![download.jfif](data:image/jpeg;base64,...)

# %%
model.add(tf.keras.layers.Dense(256, input_shape = x_train.shape, activation='sigmoid'))  #input layer
model.add(tf.keras.layers.Dense(256, activation='sigmoid'))   #hidden layer
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))     #output layer

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 1s 5ms/step - loss: 0.6678 - accuracy: 0.6374
# Epoch 2/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6627 - accuracy: 0.5934
# Epoch 3/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6724 - accuracy: 0.5934
# Epoch 4/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6712 - accuracy: 0.6374
# Epoch 5/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6793 - accuracy: 0.6198
# Epoch 6/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.6308
# Epoch 7/1000
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6732 - accuracy: 0.6022
# Epoch 8/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6631 - accuracy: 0.6374
# Epoch 9/1000
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6622 - accuracy: 0.6374
# Epoch 10/1000
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.5877
# [0.6872177124023438, 0.5877193212509155]
